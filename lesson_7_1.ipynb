# %%
import requests
url = 'https://seat.tpml.edu.tw/sm/service/getAllArea'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    print(response.text)
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# ...

# %%
# json online viewer 中txt 貼入上面"[{"areaId":3202,"branchName":"稻香分館","floorName":"7F","areaName":"資訊檢索區","freeCount":3,"totalCount":6},{"areaId":3203,"branchName":"稻香分館","floorName":"8F","areaName":"討論室","freeCount":2,"totalCount":2},{"areaId":3204,"branchName":"稻香分館","floorName":"9F","areaName":"自修室","freeCount":43,"totalCount":93},{"areaId":3209,"branchName":"總館","floorName":"1F","areaName":"數位e樂園","freeCount":20,"totalCount":36},{"areaId":3211,"branchName":"總館","floorName":"6F","areaName":"自修室","freeCount":193,"totalCount":240},{"areaId":3212,"branchName":"總館","floorName":"8F","areaName":"視聽資料閱覽室","freeCount":24,"totalCount":24},{"areaId":3213,"branchName":"總館","floorName":"8F","areaName":"親子欣賞室","freeCount":3,"totalCount":3},{"areaId":3214,"branchName":"總館","floorName":"8F","areaName":"團體欣賞室","freeCount":0,"totalCount":62},{"areaId":3215,"branchName":"總館","floorName":"8F","areaName":"兒童視聽資料閱覽室","freeCount":10,"totalCount":10},{"areaId":3216,"branchName":"總館","floorName":"8F","areaName":"VOD隨選視聽區","freeCount":6,"totalCount":6},{"areaId":3205,"branchName":"廣慈分館","floorName":"3F","areaName":"自修室","freeCount":65,"totalCount":82},{"areaId":3206,"branchName":"廣慈分館","floorName":"3F","areaName":"筆電區","freeCount":31,"totalCount":49},{"areaId":3217,"branchName":"廣慈分館","floorName":"3F","areaName":"10人討論室","freeCount":1,"totalCount":1},{"areaId":3218,"branchName":"廣慈分館","floorName":"3F","areaName":"6人討論室","freeCount":2,"totalCount":2},{"areaId":3208,"branchName":"廣慈分館","floorName":"4F","areaName":"電腦區","freeCount":2,"totalCount":5},{"areaId":3207,"branchName":"西湖分館","floorName":"B1","areaName":"自修區","freeCount":162,"totalCount":195},{"areaId":3200,"branchName":"西湖分館","floorName":"3F","areaName":"個人視聽區","freeCount":8,"totalCount":8},{"areaId":3201,"branchName":"西湖分館","floorName":"3F","areaName":"團體視聽小間","freeCount":5,"totalCount":5}]
# 再用view檢視內容

# %%
import requests
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_text = response.text
    print(type(all_text))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'str'>

# %%
import requests
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data)
dataFrame
# Out:
#             sno                       sna  tot  sbi   sarea
# 0     500101001        YouBike2.0_捷運科技大樓站   28    5     大安區  \
# 1     500101002    YouBike2.0_復興南路二段273號前   21    9     大安區
# 2     500101003      YouBike2.0_國北教大實小東側門   16    2     大安區
# 3     500101004         YouBike2.0_和平公園東側   11    2     大安區
# 4     500101005      YouBike2.0_辛亥復興路口西北側   16   12     大安區
# ...         ...                       ...  ...  ...     ...
# 1275  500119087      YouBike2.0_臺大總圖書館西南側   30   19    臺大專區
# 1276  500119088        YouBike2.0_臺大黑森林西側   20    0    臺大專區
# 1277  500119089        YouBike2.0_臺大獸醫館南側   24    1    臺大專區
# 1278  500119090      YouBike2.0_臺大新體育館東南側   40   28    臺大專區
# 1279  500119091  YouBike2.0_臺大明達館北側(員工宿舍)   18    2  臺大公館校區
#
#                      mday       lat        lng             ar     sareaen
# 0     2023-05-27 11:14:14  25.02605  121.54360    復興南路二段235號前  Daan Dist.  \
# 1     2023-05-27 11:12:14  25.02565  121.54357   復興南路二段273號西側  Daan Dist.
# ...

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    5     大安區  2023-05-27 11:14:14  \
# 1       YouBike2.0_復興南路二段273號前   21    9     大安區  2023-05-27 11:12:14
# 2         YouBike2.0_國北教大實小東側門   16    2     大安區  2023-05-27 11:09:04
# 3            YouBike2.0_和平公園東側   11    2     大安區  2023-05-27 11:01:16
# 4         YouBike2.0_辛亥復興路口西北側   16   12     大安區  2023-05-27 11:14:14
# ...                        ...  ...  ...     ...                  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   19    臺大專區  2023-05-27 11:06:16
# 1276        YouBike2.0_臺大黑森林西側   20    0    臺大專區  2023-05-27 11:10:11
# 1277        YouBike2.0_臺大獸醫館南側   24    1    臺大專區  2023-05-27 11:14:15
# 1278      YouBike2.0_臺大新體育館東南側   40   28    臺大專區  2023-05-27 11:14:15
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    2  臺大公館校區  2023-05-27 10:35:16
#
#                  ar  bemp act
# 0       復興南路二段235號前    20   1
# 1      復興南路二段273號西側    12   1
# 2       和平東路二段96巷7號    13   1
# ...

# %%
#選取欄位
dataFrame[['sna', 'tot', 'sbi']]
# Out:
#                            sna  tot  sbi
# 0           YouBike2.0_捷運科技大樓站   28    5
# 1       YouBike2.0_復興南路二段273號前   21    9
# 2         YouBike2.0_國北教大實小東側門   16    2
# 3            YouBike2.0_和平公園東側   11    2
# 4         YouBike2.0_辛亥復興路口西北側   16   12
# ...                        ...  ...  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   19
# 1276        YouBike2.0_臺大黑森林西側   20    0
# 1277        YouBike2.0_臺大獸醫館南側   24    1
# 1278      YouBike2.0_臺大新體育館東南側   40   28
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    2
#
# [1280 rows x 3 columns]

# %%
#選取列(slice)
dataFrame[67:72]
# Out:
#                            sna  tot  sbi sarea                 mday
# 67    YouBike2.0_敦化南路二段293巷口南側   14    1   大安區  2023-05-27 11:01:16  \
# 68           YouBike2.0_敦化基隆路口   29    1   大安區  2023-05-27 11:14:14
# 69       YouBike2.0_安和路二段181巷口   17    0   大安區  2023-05-27 11:01:04
# 70  YouBike2.0_臨江街夜市(通化街101巷口)   30    5   大安區  2023-05-27 11:11:16
# 71       YouBike2.0_臨江街夜市(基隆路)   17    0   大安區  2023-05-27 11:11:04
#
#                ar  bemp act
# 67  敦化南路二段293巷口南側    13   1
# 68     敦化南路二段218號    26   1
# 69      安和路二段185號    17   1
# 70        通化街111號    23   1
# 71      基隆路二段108號    14   1

# %%
#同時選取欄例
#loc[index,column],iloc[index,column]
dataFrame.loc[100:120,['sna','sarea']]
# Out:
#                             sna sarea
# 100  YouBike2.0_捷運大安森林公園站(5號出口)   大安區
# 101           YouBike2.0_信義建國路口   大安區
# 102             YouBike2.0_東豐公園   大安區
# 103     YouBike2.0_德安公園(四維路66巷)   大安區
# 104    YouBike2.0_捷運忠孝復興站(5號出口)   大安區
# 105    YouBike2.0_捷運忠孝敦化站(2號出口)   大安區
# 106    YouBike2.0_捷運忠孝敦化站(7號出口)   大安區
# 107          YouBike2.0_瑞安街208巷   大安區
# 108          YouBike2.0_樂利路21巷口   大安區
# 109  YouBike2.0_捷運科技大樓站(台北教育大學)   大安區
# 110   YouBike2.0_捷運國父紀念館站(2號出口)   大安區
# 111             YouBike2.0_仁愛醫院   大安區
# 112    YouBike2.0_捷運信義安和站(4號出口)   大安區
# 113             YouBike2.0_成功國宅   大安區
# 114           YouBike2.0_仁愛延吉街口   大安區
# 115    YouBike2.0_捷運信義安和站(1號出口)   大安區
# 116      YouBike2.0_敦化南路二段103巷口   大安區
# 117      YouBike2.0_復興南路二段128巷口   大安區
# 118         YouBike2.0_和平東建國南路口   大安區
# 119             YouBike2.0_芳蘭山莊   大安區
# 120      YouBike2.0_復興南路一段126巷口   大安區

# %%
dataFrame.iloc[100:120,[0,3]]
# Out:
#                             sna sarea
# 100  YouBike2.0_捷運大安森林公園站(5號出口)   大安區
# 101           YouBike2.0_信義建國路口   大安區
# 102             YouBike2.0_東豐公園   大安區
# 103     YouBike2.0_德安公園(四維路66巷)   大安區
# 104    YouBike2.0_捷運忠孝復興站(5號出口)   大安區
# 105    YouBike2.0_捷運忠孝敦化站(2號出口)   大安區
# 106    YouBike2.0_捷運忠孝敦化站(7號出口)   大安區
# 107          YouBike2.0_瑞安街208巷   大安區
# 108          YouBike2.0_樂利路21巷口   大安區
# 109  YouBike2.0_捷運科技大樓站(台北教育大學)   大安區
# 110   YouBike2.0_捷運國父紀念館站(2號出口)   大安區
# 111             YouBike2.0_仁愛醫院   大安區
# 112    YouBike2.0_捷運信義安和站(4號出口)   大安區
# 113             YouBike2.0_成功國宅   大安區
# 114           YouBike2.0_仁愛延吉街口   大安區
# 115    YouBike2.0_捷運信義安和站(1號出口)   大安區
# 116      YouBike2.0_敦化南路二段103巷口   大安區
# 117      YouBike2.0_復興南路二段128巷口   大安區
# 118         YouBike2.0_和平東建國南路口   大安區
# 119             YouBike2.0_芳蘭山莊   大安區
